# %%
"This is a coding cell"
# Out:
# 'This is a coding cell'

# %% [markdown]
# This is a markdown cell

# %%
# Executed by using the Run Button beside the Cell

2 + 2
# Out:
# 4

# %%
# Executed by using CTRL+Enter

2 + 2
# Out:
# 4

# %%
# Executed by using SHIFT+Enter

3+3
# Out:
# 6

# %%
# Only the Last Line is Printed

2+2
3*3
# Out:
# 9

# %%
# This ensures all Lines are being Printed

print(2 + 2)
print(3 * 3)
# Out:
# 4
# 9

# %%
# Don't need a 'Print' on the last line as this will Print anyways

print(2 + 2)
(3 * 3)
# Out:
# 4
# 9

# %%
# This is a comment

# %%
# This is a comment

2 + 2 # This adds 2 and 2
# Out:
# 4

# %% [markdown]
# MARKDOWN COMMANDS
#
# Headings:
#
# # H1
# ## H2
# ### H3
#
# Bold
# **Bold Text**
#
# Italic
# *Italicised Text Here*
#
# Blockquote
# > blockquote
#
# Ordered List
#
# 1. First Item
# 2. Second Item
# 3. Third Item
#
# Unordered List
#
# - First Item
# - Second Item
# - Third Item
#
# Code
#
# `code`
#
# Horizontal Rule
#
# ---
#
# Link
#
# [Title] (www.example.com)
#
# Image
#
# ![Image Title](image.jpg)
